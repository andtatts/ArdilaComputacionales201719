# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#solution to the 1D wave equation
x=np.linspace(0,1,1000)
u0=np.exp(-((x-0.3)**2) /0.01)
plt.figure(1)
plt.plot(x,u0)
plt.show()

# %%
c=1
dx=(x[1]-x[0])
dt=0.0005
gamma=(c*dt/dx)**2
u1=np.zeros(np.size(x))
upres=np.copy(u0)
#loops over the space u is future u0 is past or initial
for i in range(1,np.size(x)-1):
    u1[i]=(gamma/2)*(u0[i+1]-2*u0[i]+u0[i-1])+u0[i]
u1[999]=0.0
u1[0]=0.0
upresente=np.copy(u1)
upast=np.copy(u0)
plt.plot(x,u0,color='b')
plt.plot(x,u,color='y')
plt.show()

# %%
tiempototal=80000
ufut=np.zeros(np.size(x))
for j in range(tiempototal-1):
    for i in range(np.size(x)-1):
        ufut[i]=(gamma/2)*(upresente[i+1]-2*upresente[i]+upresente[i-1])+upast[i]
        #ufut[i]=gamma*(upresente[i+1]-upast[i-1])+2*(1-gamma)*upresente[i]+upresente[i-1] 
    upres=np.copy(ufut)
    upast=np.copy(upresente)
plt.plot(x,u0)
plt.plot(x,ufut)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-7e8723c801b3> in <module>()
#       3 for j in range(tiempototal-1):
#       4     for i in range(np.size(x)-1):
# ----> 5         ufut[i]=(gamma/2)*(upresente[i+1]-2*upresente[i]+upresente[i-1])+upast[i]
#       6         #ufut[i]=gamma*(upresente[i+1]-upast[i-1])+2*(1-gamma)*upresente[i]+upresente[i-1]
#       7     upres=np.copy(ufut)
#
# KeyboardInterrupt:
